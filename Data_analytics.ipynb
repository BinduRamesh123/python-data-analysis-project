# %% [markdown]
# Project on Pandas-task: dataset with set of attributes : **customer purchase behaviour analysis **
#
# business problems: an ecommerce company should:
#
# understand customer purchasing behaviour clean raw user data generate insights for business decisions
#
# dataset: option 1: download option 2: create one
#
# features that are expected:
#
# customer_id age gender city signup_data purchased _amount purchased
#
# task:
#
# data understanding and inspection' data cleaning feature engineering > extract signupmonth and signup week Aggregations and group by > average purchase by city > purchase count by gender > montly revenue trend > percentage of customer purchasing>1000 data filtering and business insights > customers that signed up but never purchased > cities with highest revenue > age group with highest average purchased final clean dataset > no missing values > numeric encoded variable > clean featurecode
# ```

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/customer_dataset_practice.csv')
df
# Out:
#    customer_id   age  gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0    Male  Bangalore  15-11-2024           2450.75
# 1      CUST002   NaN  Female        NaN  16-11-2024               NaN
# 2      CUST003  34.0     NaN      Delhi         NaN           1200.50
# 3      CUST004  41.0    Male     Mumbai  18-11-2024              0.00
# 4      CUST005   NaN  Female    Chennai  19-11-2024              0.00
# 5      CUST006  29.0     NaN  Hyderabad  20-11-2024               NaN
# 6      CUST007  38.0    Male        NaN         NaN           1999.99
# 7      CUST008   NaN  Female      Delhi  22-11-2024            500.00
# 8      CUST009  22.0     NaN  Bangalore  23-11-2024               NaN
# 9      CUST010  30.0    Male    Chennai  24-11-2024           2750.00
# 10     CUST011  27.0  Female     Mumbai  25-11-2024            800.00
# 11     CUST012  45.0     NaN  Hyderabad         NaN           1500.50
# ...

# %%
df.tail()
# Out:
#    customer_id   age  gender       city signup_date  purchased_amount  \
# 10     CUST011  27.0  Female     Mumbai  25-11-2024            800.00
# 11     CUST012  45.0     NaN  Hyderabad         NaN           1500.50
# 12     CUST013   NaN    Male        NaN  27-11-2024               NaN
# 13     CUST014  33.0  Female      Delhi  28-11-2024           3200.75
# 14     CUST015  40.0    Male       Pune  29-11-2024            999.99
#
#    purchased
# 10       Yes
# 11       NaN
# 12       Yes
# 13       Yes
# 14        No

# %%
df.head()
# Out:
#   customer_id   age  gender       city signup_date  purchased_amount purchased
# 0     CUST001  25.0    Male  Bangalore  15-11-2024           2450.75       Yes
# 1     CUST002   NaN  Female        NaN  16-11-2024               NaN       Yes
# 2     CUST003  34.0     NaN      Delhi         NaN           1200.50       Yes
# 3     CUST004  41.0    Male     Mumbai  18-11-2024              0.00       NaN
# 4     CUST005   NaN  Female    Chennai  19-11-2024              0.00        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       15 non-null     object
#  1   age               11 non-null     float64
#  2   gender            11 non-null     object
#  3   city              12 non-null     object
#  4   signup_date       12 non-null     object
#  5   purchased_amount  11 non-null     float64
#  6   purchased         12 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 972.0+ bytes

# %%
df.describe()
# Out:
#              age  purchased_amount
# count  11.000000         11.000000
# mean   33.090909       1400.225455
# std     7.272614       1087.619973
# min    22.000000          0.000000
# 25%    28.000000        650.000000
# 50%    33.000000       1200.500000
# 75%    39.000000       2225.370000
# max    45.000000       3200.750000

# %%
df['age'].fillna(df['age'].median(),inplace=True)
df
# Out:
# /tmp/ipython-input-4156218647.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)
#    customer_id   age  gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0    Male  Bangalore  15-11-2024           2450.75
# 1      CUST002  33.0  Female        NaN  16-11-2024               NaN
# 2      CUST003  34.0     NaN      Delhi         NaN           1200.50
# 3      CUST004  41.0    Male     Mumbai  18-11-2024              0.00
# ...

# %%
df['signup_date'].fillna(method='ffill',inplace=True)
df
# Out:
# /tmp/ipython-input-3187774780.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['signup_date'].fillna(method='ffill',inplace=True)
# /tmp/ipython-input-3187774780.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['signup_date'].fillna(method='ffill',inplace=True)
#    customer_id   age  gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0    Male  Bangalore  15-11-2024           2450.75
# ...

# %%
df['gender']=df['gender'].map({'Male':0,'Female':1})
df
# Out:
#    customer_id   age  gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0     0.0  Bangalore  15-11-2024           2450.75
# 1      CUST002  33.0     1.0        NaN  16-11-2024               NaN
# 2      CUST003  34.0     NaN      Delhi  16-11-2024           1200.50
# 3      CUST004  41.0     0.0     Mumbai  18-11-2024              0.00
# 4      CUST005  33.0     1.0    Chennai  19-11-2024              0.00
# 5      CUST006  29.0     NaN  Hyderabad  20-11-2024               NaN
# 6      CUST007  38.0     0.0        NaN  20-11-2024           1999.99
# 7      CUST008  33.0     1.0      Delhi  22-11-2024            500.00
# 8      CUST009  22.0     NaN  Bangalore  23-11-2024               NaN
# 9      CUST010  30.0     0.0    Chennai  24-11-2024           2750.00
# 10     CUST011  27.0     1.0     Mumbai  25-11-2024            800.00
# 11     CUST012  45.0     NaN  Hyderabad  25-11-2024           1500.50
# ...

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=3)
df["gender"]=imputer.fit_transform(df[["gender"]])
df
# Out:
#    customer_id   age    gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0  0.000000  Bangalore  15-11-2024           2450.75
# 1      CUST002  33.0  1.000000      Delhi  16-11-2024              0.00
# 2      CUST003  34.0  0.454545      Delhi  16-11-2024           1200.50
# 3      CUST004  41.0  0.000000     Mumbai  18-11-2024              0.00
# 4      CUST005  33.0  1.000000    Chennai  19-11-2024              0.00
# 5      CUST006  29.0  0.454545  Hyderabad  20-11-2024              0.00
# 6      CUST007  38.0  0.000000      Delhi  20-11-2024           1999.99
# 7      CUST008  33.0  1.000000      Delhi  22-11-2024            500.00
# 8      CUST009  22.0  0.454545  Bangalore  23-11-2024              0.00
# 9      CUST010  30.0  0.000000    Chennai  24-11-2024           2750.00
# 10     CUST011  27.0  1.000000     Mumbai  25-11-2024            800.00
# 11     CUST012  45.0  0.454545  Hyderabad  25-11-2024           1500.50
# ...

# %%
df['city'].fillna(df['city'].mode()[0],inplace=True)
df
# Out:
# /tmp/ipython-input-2657585589.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['city'].fillna(df['city'].mode()[0],inplace=True)
#    customer_id   age    gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0  0.000000  Bangalore  15-11-2024           2450.75
# 1      CUST002  33.0  1.000000      Delhi  16-11-2024              0.00
# 2      CUST003  34.0  0.454545      Delhi  16-11-2024           1200.50
# 3      CUST004  41.0  0.000000     Mumbai  18-11-2024              0.00
# ...

# %%
df['purchased_amount'].fillna(df['purchased_amount'].mode()[0],inplace=True)
df
# Out:
# /tmp/ipython-input-3051596271.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['purchased_amount'].fillna(df['purchased_amount'].mode()[0],inplace=True)
#    customer_id   age  gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0     0.0  Bangalore  15-11-2024           2450.75
# 1      CUST002  33.0     1.0        NaN  16-11-2024              0.00
# 2      CUST003  34.0     NaN      Delhi  16-11-2024           1200.50
# ...

# %%
df['purchased']=df['purchased'].map({'Yes':1,'No':0})
df
# Out:
#    customer_id   age    gender       city signup_date  purchased_amount  \
# 0      CUST001  25.0  0.000000  Bangalore  15-11-2024           2450.75
# 1      CUST002  33.0  1.000000      Delhi  16-11-2024              0.00
# 2      CUST003  34.0  0.454545      Delhi  16-11-2024           1200.50
# 3      CUST004  41.0  0.000000     Mumbai  18-11-2024              0.00
# 4      CUST005  33.0  1.000000    Chennai  19-11-2024              0.00
# 5      CUST006  29.0  0.454545  Hyderabad  20-11-2024              0.00
# 6      CUST007  38.0  0.000000      Delhi  20-11-2024           1999.99
# 7      CUST008  33.0  1.000000      Delhi  22-11-2024            500.00
# 8      CUST009  22.0  0.454545  Bangalore  23-11-2024              0.00
# 9      CUST010  30.0  0.000000    Chennai  24-11-2024           2750.00
# 10     CUST011  27.0  1.000000     Mumbai  25-11-2024            800.00
# 11     CUST012  45.0  0.454545  Hyderabad  25-11-2024           1500.50
# ...
